# %% [markdown]
# <a href="https://colab.research.google.com/github/cenriquegit/APP-KINGSOFT-LEAGUE/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade tensorflow matplotlib numpy

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np

# Cargar los datos
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Etiquetas de las clases
labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
          "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Mostrar algunas imágenes
plt.figure(figsize=(14, 8))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.imshow(X_train[i], cmap="binary")
    plt.title(labels[y_train[i]])
    plt.axis("off")
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),   # Capa de entrada
    keras.layers.Dense(128, activation='relu'),   # Capa oculta
    keras.layers.Dense(10, activation='softmax')  # Capa de salida
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7806 - loss: 0.6312 - val_accuracy: 0.8366 - val_loss: 0.4454
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8585 - loss: 0.3927 - val_accuracy: 0.8599 - val_loss: 0.3956
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8743 - loss: 0.3420 - val_accuracy: 0.8737 - val_loss: 0.3582
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8844 - loss: 0.3140 - val_accuracy: 0.8631 - val_loss: 0.3719
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8893 - loss: 0.2991 - val_accuracy: 0.8570 - val_loss: 0.3924
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8981 - loss: 0.2787 - val_accuracy: 0.8732 - val_loss: 0.3486
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8999 - loss: 0.2726 - val_accuracy: 0.8747 - val_loss: 0.3481
# Epoch 8/50
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nPrecisión en el conjunto de prueba:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8777 - loss: 0.5597
#
# Precisión en el conjunto de prueba: 0.8797000050544739

# %%
plt.plot(history.history['accuracy'], label='Precisión entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.show()

# %% [markdown]
# REGRESION LINEAL SIMPLE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
temperatura = np.array([15, 16, 18, 20, 21, 23, 25, 27, 30, 32])
ventas = np.array([500, 520, 560, 580, 600, 640, 680, 700, 760, 800])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    temperatura.reshape(-1, 1), ventas, test_size=0.2, random_state=42
)


model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(temperatura, ventas, color="blue", label="Datos reales")
plt.plot(temperatura, model.predict(temperatura.reshape(-1, 1)), color="red", label="Línea de regresión")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Ventas")
plt.legend()
plt.show()

# %%
r_sq = model.score(X_test, y_test)
print('Coeficiente de determinación (R²):', r_sq)
# Out:
# Coeficiente de determinación (R²): 0.9996659605670523
